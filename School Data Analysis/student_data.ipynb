# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('student_data.txt', sep=",")
df
# Out:
#                              name  school_rating   size  reduced_lunch  \
# 0     Allendale Elementary School            5.0  851.0           10.0
# 1             Anderson Elementary            2.0  412.0           71.0
# 2                Avoca Elementary            4.0  482.0           43.0
# 3                   Bailey Middle            0.0  394.0           91.0
# 4             Barfield Elementary            4.0  948.0           26.0
# ..                            ...            ...    ...            ...
# 342  Winfree Bryant Middle School            3.0  611.0           57.0
# 343    Winstead Elementary School            5.0  515.0            8.0
# 344           Woodland Elementary            4.0  424.0           55.0
# 345        Woodland Middle School            5.0  866.0            2.0
# 346                 Wright Middle            0.0  829.0           89.0
#
#      state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# ...

# %%
df_5_rating = df[df['school_rating'] == 5.0]
print(df_5_rating['full_time_teachers'].mean())
print(df_5_rating['stu_teach_ratio'].mean())
# Out:
# 45.35897435897436
# 17.780769230769227

# %%
df_0_rating= df[df['school_rating'] == 0.0]
print(df_0_rating['full_time_teachers'].mean())
print(df_0_rating['stu_teach_ratio'].mean())
# Out:
# 35.97674418604651
# 13.58372093023256

# %%
df_1_rating= df[df['school_rating'] == 1.0]
print(df_1_rating['full_time_teachers'].mean())
print(df_1_rating['stu_teach_ratio'].mean())
# Out:
# 44.175
# 14.912500000000003

# %%
df_2_rating= df[df['school_rating'] == 2.0]
print(df_2_rating['full_time_teachers'].mean())
print(df_2_rating['stu_teach_ratio'].mean())
# Out:
# 42.93181818181818
# 14.43409090909091

# %%
df_3_rating= df[df['school_rating'] == 3.0]
print(df_3_rating['full_time_teachers'].mean())
print(df_3_rating['stu_teach_ratio'].mean())
# Out:
# 49.535714285714285
# 15.085714285714284

# %%
df_4_rating= df[df['school_rating'] == 4.0]
print(df_4_rating['full_time_teachers'].mean())
print(df_4_rating['stu_teach_ratio'].mean())
# Out:
# 47.43023255813954
# 15.323255813953487

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['state_percentile_15', 'avg_score_15'], dtype='object')

# %%
df[df['state_percentile_15'].isna()]
# Out:
#                             name  school_rating   size  reduced_lunch  \
# 29             Carmel Elementary            5.0  583.0           21.0
# 63   East End Preparatory School            4.0  383.0           87.0
# 157     Ketron Elementary School            1.0  722.0           78.0
# 166          Lead Prep Southeast            2.0  235.0           77.0
# 203               Murrell School            0.0   71.0           87.0
# 213          North Middle School            1.0  344.0           74.0
#
#      state_percentile_16  state_percentile_15  stu_teach_ratio  \
# 29                  93.7                  NaN             14.9
# 63                  81.9                  NaN             22.5
# 157                 12.7                  NaN             17.6
# 166                 47.8                  NaN             14.6
# 203                  0.2                  NaN              4.7
# 213                 27.1                  NaN             19.1
#
# ...

# %%
df[df['avg_score_15'].isna()]
# Out:
#                             name  school_rating   size  reduced_lunch  \
# 29             Carmel Elementary            5.0  583.0           21.0
# 63   East End Preparatory School            4.0  383.0           87.0
# 157     Ketron Elementary School            1.0  722.0           78.0
# 166          Lead Prep Southeast            2.0  235.0           77.0
# 203               Murrell School            0.0   71.0           87.0
# 213          North Middle School            1.0  344.0           74.0
#
#      state_percentile_16  state_percentile_15  stu_teach_ratio  \
# 29                  93.7                  NaN             14.9
# 63                  81.9                  NaN             22.5
# 157                 12.7                  NaN             17.6
# 166                 47.8                  NaN             14.6
# 203                  0.2                  NaN              4.7
# 213                 27.1                  NaN             19.1
#
# ...

# %%
df['name'].value_counts().head(10)
# Out:
# Liberty Elementary           3
# Rock Springs Elementary      2
# Johnson Elementary           2
# South Side Elementary        2
# Eakin Elementary             2
# Hazelwood Elementary         1
# Goodlettsville Elementary    1
# Siegel High School           1
# Rossview Middle School       1
# Sevier Middle School         1
# Name: name, dtype: int64

# %%
df[df['name'] == 'Liberty Elementary']
# Out:
#                    name  school_rating   size  reduced_lunch  \
# 171  Liberty Elementary            4.0  522.0           46.0
# 172  Liberty Elementary            2.0  717.0           62.0
# 173  Liberty Elementary            3.0  807.0           63.0
#
#      state_percentile_16  state_percentile_15  stu_teach_ratio school_type  \
# 171                 86.4                 93.5             11.3      Public
# 172                 31.7                 20.5             16.6      Public
# 173                 60.1                 52.4             13.4      Public
#
#      avg_score_15  avg_score_16  full_time_teachers  percent_black  \
# 171          86.2          81.0                46.0           13.6
# 172          29.2          37.3                43.0            1.3
# 173          52.6          57.4                60.0           27.3
#
#      percent_white  percent_asian  percent_hispanic
# 171           47.3            3.6              31.6
# ...

# %%
df_5_rating = df[df['school_rating'] == 5.0]
df_5_rating
# Out:
#                             name  school_rating    size  reduced_lunch  \
# 0    Allendale Elementary School            5.0   851.0           10.0
# 7               Beech Elementary            5.0   612.0           16.0
# 13    Blackman Elementary School            5.0   880.0           25.0
# 20         Brentwood High School            5.0  1689.0            4.0
# 21       Brentwood Middle School            5.0  1261.0            3.0
# ..                           ...            ...     ...            ...
# 302           Trinity Elementary            5.0   595.0            8.0
# 309      Union Elementary School            5.0   528.0           15.0
# 314      Walnut Grove Elementary            5.0   662.0            9.0
# 343   Winstead Elementary School            5.0   515.0            8.0
# 345       Woodland Middle School            5.0   866.0            2.0
#
#      state_percentile_16  state_percentile_15  stu_teach_ratio school_type  \
# ...

# %%
# %matplotlib inline
col =['percent_black','percent_white','percent_asian','percent_hispanic']
df_0_rating[col].plot()

# %%
df_5_rating[col].plot()

# %%
df_5_rating[col].plot()

# %%
df_5_rating[col]
# Out:
#      percent_black  percent_white  percent_asian  percent_hispanic
# 0              2.9           85.5            1.6               5.6
# 7              4.2           90.5            0.3               3.1
# 13            17.0           67.3            6.9               5.7
# 20             3.1           83.8            6.9               3.6
# 21             3.2           83.3            6.7               2.8
# ..             ...            ...            ...               ...
# 302            2.2           86.2            4.0               3.5
# 309            8.1           86.4            1.5               1.3
# 314            1.7           89.4            4.1               2.6
# 343            3.3           87.4            3.1               4.1
# 345            4.5           77.6           10.0               4.4
#
# [78 rows x 4 columns]

# %%
df.columns.unique()
# Out:
# Index(['name', 'school_rating', 'size', 'reduced_lunch', 'state_percentile_16',
#        'state_percentile_15', 'stu_teach_ratio', 'school_type', 'avg_score_15',
#        'avg_score_16', 'full_time_teachers', 'percent_black', 'percent_white',
#        'percent_asian', 'percent_hispanic'],
#       dtype='object')

# %%
df[df['name'].isin([tes])]
# Out:
# Empty DataFrame
# Columns: [name, school_rating, size, reduced_lunch, state_percentile_16, state_percentile_15, stu_teach_ratio, school_type, avg_score_15, avg_score_16, full_time_teachers, percent_black, percent_white, percent_asian, percent_hispanic]
# Index: []

# %%
test = (df_LE['name'].value_counts() > 2).to_frame()
test[test['name'] == True]
# Out:
#                     name
# Liberty Elementary  True

# %%
def removing_duplicates(column_name,df):
    colu=[]
    for column in df.columns:
        colu.append(column)
    if colu[0] == column_name:
        v_count = (df[colu[0]].value_counts() > 1).to_frame()
        v_count = v_count[v_count[colu[0]] == True]
        v_count = v_count.reset_index()
        tes = v_count['index'].to_list()
        df_du = df.drop(df.loc[df[colu[0]].isin(tes)].index)
        return (tes,df_du)
    else:
        return (print('Column name entered did not match any of the columns in dataframe'))

# %%
df_dup = removing_duplicates('name',df)

# %%
df_du = df_dup['df_du']
df_du
# Out:
#                              name  school_rating   size  reduced_lunch  \
# 0     Allendale Elementary School            5.0  851.0           10.0
# 1             Anderson Elementary            2.0  412.0           71.0
# 2                Avoca Elementary            4.0  482.0           43.0
# 3                   Bailey Middle            0.0  394.0           91.0
# 4             Barfield Elementary            4.0  948.0           26.0
# ..                            ...            ...    ...            ...
# 342  Winfree Bryant Middle School            3.0  611.0           57.0
# 343    Winstead Elementary School            5.0  515.0            8.0
# 344           Woodland Elementary            4.0  424.0           55.0
# 345        Woodland Middle School            5.0  866.0            2.0
# 346                 Wright Middle            0.0  829.0           89.0
#
#      state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# ...

# %%
dupcol = df_dup['tes']
dupcol
# Out:
# ['Liberty Elementary',
#  'Rock Springs Elementary',
#  'Johnson Elementary',
#  'South Side Elementary',
#  'Eakin Elementary']

# %%
dfnew = []
for i in dupcol:
        dfmean = (df[df['name'].isin([i])]).mean().to_frame().reset_index()
        dfN = pd.pivot_table(dfmean, columns ='index')
        dfN.insert(0, "name", [i], True)
        st= df[(df['name'].isin([i]))].head(1)
        stval = st.iloc[0]['school_type']
        dfN.insert(0, "school_type", [stval],True)
        df_du.append(dfN, sort=False)
        dfnew.append(dfN)
        qqqqqq
#table.insert(0, "name", ['Liberty Elementary'], True)
#table.insert(0, "school_type", ['Public'], True) 

#print(i)
# Out:
# index school_type                   name  avg_score_15  avg_score_16  \
# 0          Public  South Side Elementary          52.8          50.3
#
# index  full_time_teachers  percent_asian  percent_black  percent_hispanic  \
# 0                    28.5            0.9            8.6             24.45
#
# index  percent_white  reduced_lunch  school_rating   size  \
# 0              59.85           72.0            2.5  391.0
#
# index  state_percentile_15  state_percentile_16  stu_teach_ratio
# 0                    51.95                 49.3             13.8

# %%
dfnew[0]
# Out:
# index school_type                name  avg_score_15  avg_score_16  \
# 0          Public  Liberty Elementary          56.0     58.566667
#
# index  full_time_teachers  percent_asian  percent_black  percent_hispanic  \
# 0               49.666667       1.333333      14.066667         17.166667
#
# index  percent_white  reduced_lunch  school_rating   size  \
# 0          60.566667           57.0            3.0  682.0
#
# index  state_percentile_15  state_percentile_16  stu_teach_ratio
# 0                55.466667                 59.4        13.766667

# %%
st=df[(df['name'].isin(['Liberty Elementary']))].head(1)
stval =st.iloc[0]['school_type']
stval
# Out:
# 'Public'

# %%
(df[df['name'] == 'Liberty Elementary']).mean().to_frame().reset_index()
# Out:
#                   index           0
# 0         school_rating    3.000000
# 1                  size  682.000000
# 2         reduced_lunch   57.000000
# 3   state_percentile_16   59.400000
# 4   state_percentile_15   55.466667
# 5       stu_teach_ratio   13.766667
# 6          avg_score_15   56.000000
# 7          avg_score_16   58.566667
# 8    full_time_teachers   49.666667
# 9         percent_black   14.066667
# 10        percent_white   60.566667
# 11        percent_asian    1.333333
# 12     percent_hispanic   17.166667

# %%
df_LE = df_LE.mean()
df_LE
# Out:
# school_rating            3.20
# size                   689.00
# reduced_lunch           49.60
# state_percentile_16     63.26
# state_percentile_15     60.42
# stu_teach_ratio         14.52
# avg_score_15            59.56
# avg_score_16            61.08
# full_time_teachers      47.40
# percent_black           13.84
# percent_white           65.68
# percent_asian            2.16
# percent_hispanic        12.94
# dtype: float64

# %%
df_LE = df_LE.to_frame()
df_LE
# Out:
#                           0
# school_rating          3.20
# size                 689.00
# reduced_lunch         49.60
# state_percentile_16   63.26
# state_percentile_15   60.42
# stu_teach_ratio       14.52
# avg_score_15          59.56
# avg_score_16          61.08
# full_time_teachers    47.40
# percent_black         13.84
# percent_white         65.68
# percent_asian          2.16
# percent_hispanic      12.94

# %%
df_LE = df_LE.reset_index()
df_LE
# Out:
#                   index       0
# 0         school_rating    3.20
# 1                  size  689.00
# 2         reduced_lunch   49.60
# 3   state_percentile_16   63.26
# 4   state_percentile_15   60.42
# 5       stu_teach_ratio   14.52
# 6          avg_score_15   59.56
# 7          avg_score_16   61.08
# 8    full_time_teachers   47.40
# 9         percent_black   13.84
# 10        percent_white   65.68
# 11        percent_asian    2.16
# 12     percent_hispanic   12.94

# %%
table = pd.pivot_table(df_LE, columns ='index')
table
# Out:
# index  avg_score_15  avg_score_16  full_time_teachers  percent_asian  \
# 0             59.56         61.08                47.4           2.16
#
# index  percent_black  percent_hispanic  percent_white  reduced_lunch  \
# 0              13.84             12.94          65.68           49.6
#
# index  school_rating   size  state_percentile_15  state_percentile_16  \
# 0                3.2  689.0                60.42                63.26
#
# index  stu_teach_ratio
# 0                14.52

# %%
table.insert(0, "name", ['Liberty Elementary'], True)

# %%
table.insert(0, "school_type", ['Public'], True)

# %%
table
# Out:
# index school_type                name  avg_score_15  avg_score_16  \
# 0          Public  Liberty Elementary         59.56         61.08
#
# index  full_time_teachers  percent_asian  percent_black  percent_hispanic  \
# 0                    47.4           2.16          13.84             12.94
#
# index  percent_white  reduced_lunch  school_rating   size  \
# 0              65.68           49.6            3.2  689.0
#
# index  state_percentile_15  state_percentile_16  stu_teach_ratio
# 0                    60.42                63.26            14.52

# %%
df_du.append(table, sort=False)
# Out:
#                             name  school_rating   size  reduced_lunch  \
# 0    Allendale Elementary School            5.0  851.0           10.0
# 1            Anderson Elementary            2.0  412.0           71.0
# 2               Avoca Elementary            4.0  482.0           43.0
# 3                  Bailey Middle            0.0  394.0           91.0
# 4            Barfield Elementary            4.0  948.0           26.0
# ..                           ...            ...    ...            ...
# 343   Winstead Elementary School            5.0  515.0            8.0
# 344          Woodland Elementary            4.0  424.0           55.0
# 345       Woodland Middle School            5.0  866.0            2.0
# 346                Wright Middle            0.0  829.0           89.0
# 0             Liberty Elementary            3.2  689.0           49.6
#
#      state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# ...

# %%
df_du
# Out:
#                              name  school_rating   size  reduced_lunch  \
# 0     Allendale Elementary School            5.0  851.0           10.0
# 1             Anderson Elementary            2.0  412.0           71.0
# 2                Avoca Elementary            4.0  482.0           43.0
# 3                   Bailey Middle            0.0  394.0           91.0
# 4             Barfield Elementary            4.0  948.0           26.0
# ..                            ...            ...    ...            ...
# 342  Winfree Bryant Middle School            3.0  611.0           57.0
# 343    Winstead Elementary School            5.0  515.0            8.0
# 344           Woodland Elementary            4.0  424.0           55.0
# 345        Woodland Middle School            5.0  866.0            2.0
# 346                 Wright Middle            0.0  829.0           89.0
#
#      state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# ...

# %%
# Out:
#                             name  school_rating   size  reduced_lunch  \
# 0    Allendale Elementary School            5.0  851.0           10.0
# 1            Anderson Elementary            2.0  412.0           71.0
# 2               Avoca Elementary            4.0  482.0           43.0
# 3                  Bailey Middle            0.0  394.0           91.0
# 4            Barfield Elementary            4.0  948.0           26.0
# ..                           ...            ...    ...            ...
# 343   Winstead Elementary School            5.0  515.0            8.0
# 344          Woodland Elementary            4.0  424.0           55.0
# 345       Woodland Middle School            5.0  866.0            2.0
# 346                Wright Middle            0.0  829.0           89.0
# 0             Liberty Elementary            3.0  682.0           57.0
#
#      state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# ...

# %%
#df_LE = df[df['name'].isin(['Liberty Elementary', 'Rock Springs Elementary']) ]
df_drop_LE = df.drop(df.loc[df['name'].isin(['Liberty Elementary', 'Rock Springs Elementary'])].index)

# %%
df_drop_LE[df_drop_LE['name'] == 'Rock Springs Elementary']
# Out:
# Empty DataFrame
# Columns: [name, school_rating, size, reduced_lunch, state_percentile_16, state_percentile_15, stu_teach_ratio, school_type, avg_score_15, avg_score_16, full_time_teachers, percent_black, percent_white, percent_asian, percent_hispanic]
# Index: []

# %%
table.insert(0, "name", ['Liberty Elementary'], True)

# %%
table
# Out:
# index                name  avg_score_15  avg_score_16  full_time_teachers  \
# 0      Liberty Elementary          56.0     58.566667           49.666667
#
# index  percent_asian  percent_black  percent_hispanic  percent_white  \
# 0           1.333333      14.066667         17.166667      60.566667
#
# index  reduced_lunch  school_rating   size  state_percentile_15  \
# 0               57.0            3.0  682.0            55.466667
#
# index  state_percentile_16  stu_teach_ratio
# 0                     59.4        13.766667

# %%
table.insert(0, "school_type", ['Public'], True)

# %%
table
# Out:
# index school_type                name  avg_score_15  avg_score_16  \
# 0          Public  Liberty Elementary          56.0     58.566667
#
# index  full_time_teachers  percent_asian  percent_black  percent_hispanic  \
# 0               49.666667       1.333333      14.066667         17.166667
#
# index  percent_white  reduced_lunch  school_rating   size  \
# 0          60.566667           57.0            3.0  682.0
#
# index  state_percentile_15  state_percentile_16  stu_teach_ratio
# 0                55.466667                 59.4        13.766667
